# %% [markdown]
# <a href="https://colab.research.google.com/github/FancyFun/FancyFun/blob/master/PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
tech1 = pd.read_csv('/content/drive/My Drive/Data/microprocessor-clock-speed.csv')

# %%
tech1.head()
# Out:
#   Entity  ... Microprocessor clock speed (Hertz (pulses per second))
# 0  World  ...                                            1350000
# 1  World  ...                                            2060000
# 2  World  ...                                            2140000
# 3  World  ...                                            2290000
# 4  World  ...                                            1940000
#
# [5 rows x 4 columns]

# %%
tech1.shape
# Out:
# (34, 4)

# %%
mar = pd.read_csv('/content/drive/My Drive/Data/general-marriage-rate,-1961–2019.csv')

# %%
mar.head()
# Out:
#    December year  General marriage rate
# 0           1961                  38.19
# 1           1962                  37.65
# 2           1963                  37.11
# 3           1964                  37.65
# 4           1965                  38.59

# %%
mar.shape
# Out:
# (59, 2)

# %%
plt.plot(mar['General marriage rate'], color='red')
plt.plot(tech1['Microprocessor clock speed (Hertz (pulses per second))'], color='orange')

plt.xlim(-1,54)
plt.ylim(-1,54)

plt.show()

# %%
plt.plot(tech1['Microprocessor clock speed (Hertz (pulses per second))']);

# %%
broadband = pd.read_csv('/content/drive/My Drive/Data/broadband-penetration-by-country.csv')

broadband.head()
# Out:
#         Entity  ... Fixed broadband subscriptions (per 100 people) (per 100 people)
# 0  Afghanistan  ...                                           0.000829
# 1  Afghanistan  ...                                           0.000878
# 2  Afghanistan  ...                                           0.001931
# 3  Afghanistan  ...                                           0.001879
# 4  Afghanistan  ...                                           0.001832
#
# [5 rows x 4 columns]

# %%
def div(a):
  y = a/100
  return y

# %%
lala = div(mar['General marriage rate'])

mar2 = mar

mar2['newMarriage'] = lala

mar2.head()
# Out:
#    December year  General marriage rate  newMarriage
# 0           1961                  38.19       0.3819
# 1           1962                  37.65       0.3765
# 2           1963                  37.11       0.3711
# 3           1964                  37.65       0.3765
# 4           1965                  38.59       0.3859

# %%
plt.plot(mar2['newMarriage'], color="blue")
plt.plot(broadband['Fixed broadband subscriptions (per 100 people) (per 100 people)'], color='red')
plt.show()

# %%
mar2.shape
# Out:
# (59, 3)

# %%
mar2.head(5)
# Out:
#    December year  General marriage rate  newMarriage
# 0           1961                  38.19       0.3819
# 1           1962                  37.65       0.3765
# 2           1963                  37.11       0.3711
# 3           1964                  37.65       0.3765
# 4           1965                  38.59       0.3859

# %%
mar2['broadband'] = broadband['Fixed broadband subscriptions (per 100 people) (per 100 people)']

# %%
def mul(a):
  y = a*100
  return y

# %%
mar2['broadband'] = div(mar2['broadband'])
mar2['broadband'] = mul(mar2['broadband'])

# %%
plt.plot(mar2['broadband'], color='blue')

plt.plot(mar['General marriage rate'], color='red')

plt.xlim(0,50)
names = (0,5,10,15,20,25,30,35,40,45,50,55)

names2 = range(0,100)

plt.xticks(names)

plt.title('Decline in Marriage')


plt.show()

# %%
mar2.plot(x=0,y=['broadband','General marriage rate'], kind='line',figsize=(20,10))

plt.ylabel('Percentage')

plt.title('Broadband vs Marriage')

plt.show()

# %%
mar2.plot(x=0,y=['broadband','General marriage rate'], style=['o','x'], figsize=(20,10))

plt.title('Broadband vs marriage')

plt.ylabel('Percentage')

plt.show()

# %%
mar2.plot(x=0,y=['broadband','General marriage rate'], kind='bar', figsize=(20,10))

plt.title('Marriage vs Broadband')

plt.ylabel('Percentage')



plt.show()
